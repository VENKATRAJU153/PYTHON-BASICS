# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKATRAJU153/PYTHON-BASICS/blob/main/DICT_BASICS05_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Create a dictionary with 3 key-value pairs and print it.
# 2. Access and print the value of a specific key from a dictionary.
# 3. Use get() to retrieve a value safely without causing an error.
# 4. Merge two dictionaries into a new one using update().
# 5. Remove a specific key using pop() and print the updated dictionary.
# 6. Check if a key exists in a dictionary using in operator.
# 7. Retrieve all the keys from a dictionary using keys() method.
# 8. Retrieve all the values from a dictionary using values() method.
# 9. Get all key-value pairs from a dictionary using items().
# 10. Create a copy of a dictionary and verify both are independent.
# 11. Use setdefault() to insert a key only if it doesn’t exist.
# 12. Convert a list of tuples [("a",1),("b",2)] into a dictionary.
# 13. Convert two lists ["a","b"] and [1,2] into a dictionary.
# 14. Find the length of a dictionary using len().
# 15. Delete all items from a dictionary using clear().
# 16. Extract keys as a list and slice the first two.
# 17. Sort the dictionary by keys and display it.
# 18. Access a nested dictionary value, e.g., {"emp":{"name":"John","age":30}}.
# 19. Use dictionary comprehension (without loops) to create a dictionary from a string using dict(zip()).
# 20. Find the maximum and minimum value in a dictionary using built-in functions.

# %%
#Create a dictionary with 3 key-value pairs and print it.
d1 = {"name":'vihara',"quality":'best',"top":1}
print(d1)
# Out:
# {'name': 'vihara', 'quality': 'best', 'top': 1}

# %%
#2. Access and print the value of a specific key from a dictionary.
d1 = {"name":'vihara',"quality":'best',"top":1}
print(d1["top"])
# Out:
# 1

# %%
#3. Use get() to retrieve a value safely without causing an error.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
print(d1.get("top"))
print(d1.get("city"))
# Out:
# 1
# hyd

# %%
#4. Merge two dictionaries into a new one using update().
d1 = {"name":'vihara',"quality":'best',"top":1}
d2 = {"city":'hyd',"year":2020}
d1.update(d2)
d3 = d1.copy()
print(d3)
# Out:
# {'name': 'vihara', 'quality': 'best', 'top': 1, 'city': 'hyd', 'year': 2020}

# %%
#5. Remove a specific key using pop() and print the updated dictionary.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
print(d1.pop("city"))
print(d1)
# Out:
# hyd
# {'name': 'vihara', 'quality': 'best', 'top': 1, 'year': 2020}

# %%
#6. Check if a key exists in a dictionary using in operator.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
ky = input()
if ky in d1:
  print("EXIST")
else:
  print("NOT EXIST")
# Out:
# year
# EXIST

# %%
#7. Retrieve all the keys from a dictionary using keys() method.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = d1.keys()
print(x)
# Out:
# dict_keys(['name', 'quality', 'top', 'city', 'year'])

# %%
#8. Retrieve all the values from a dictionary using values() method.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = d1.values()
print(x)
# Out:
# dict_values(['vihara', 'best', 1, 'hyd', 2020])

# %%
#9. Get all key-value pairs from a dictionary using items().
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = d1.items()
print(x)
# Out:
# dict_items([('name', 'vihara'), ('quality', 'best'), ('top', 1), ('city', 'hyd'), ('year', 2020)])

# %%
#10. Create a copy of a dictionary and verify both are independent.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
d2 = d1.copy()
d2["year"]= 2010
d2["state"]= 'TS'
print(d1)
print(d2)
# Out:
# {'name': 'vihara', 'quality': 'best', 'top': 1, 'city': 'hyd', 'year': 2020}
# {'name': 'vihara', 'quality': 'best', 'top': 1, 'city': 'hyd', 'year': 2010, 'state': 'TS'}

# %%
#11. Use setdefault() to insert a key only if it doesn’t exist.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = input("enter key: ")
d1.setdefault(x)
print(d1)
# Out:
# enter key: state
# {'name': 'vihara', 'quality': 'best', 'top': 1, 'city': 'hyd', 'year': 2020, 'state': None}

# %%
#12. Convert a list of tuples [("a",1),("b",2)] into a dictionary.
l1 =[("a",1),("b",2),("c",3)]
d1 = dict(l1)
print(d1)
print(type(d1))
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# <class 'dict'>

# %%
#13. Convert two lists ["a","b"] and [1,2] into a dictionary.
l1 = ["a","b"]
l2 = [1,2]
d1 =dict(zip(l1,l2))
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
#14. Find the length of a dictionary using len().
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = len(d1)
print("length of dic is:", x)
# Out:
# length of dic is: 5

# %%
#15. Delete all items from a dictionary using clear().
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
d1.clear()
print("empty dict:", d1)
# Out:
# empty dict: {}

# %%
#16. Extract keys as a list and slice the first two.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
x = list(d1.keys())
print(type(x))
print(x[: 2])
# Out:
# <class 'list'>
# ['name', 'quality']

# %%
#17. Sort the dictionary by keys and display it.
d1 = {"name":'vihara',"quality":'best',"top":1, "city":'hyd',"year":2020}
print(sorted(d1.items()))
# Out:
# [('city', 'hyd'), ('name', 'vihara'), ('quality', 'best'), ('top', 1), ('year', 2020)]

# %%
#18. Access a nested dictionary value, e.g., {"emp":{"name":"John","age":30}}.
d1 = {"emp1":{"name":'venkat', "age":35},
      "emp2":{"name":'Raja', "age":34},
      "emp3":{"name":'YADAV', "age":33}
      }
print(d1["emp2"]["name"])
print(d1["emp3"]["age"])
# Out:
# Raja
# 33

# %%
#19. Use dictionary comprehension (without loops) to create a dictionary from a string using dict(zip()).
st1 = "abcde"
st2 = "12345"
d1 = dict(zip(st1, st2))
print(d1)
# Out:
# {'a': '1', 'b': '2', 'c': '3', 'd': '4', 'e': '5'}

# %%
#20. Find the maximum and minimum value in a dictionary using built-in functions.
d1 = {'a': 45, 'b': 63, 'c': 53, 'd': 44, 'e': 55}
x = max(d1.values())
y = min(d1.values())
print("maximum value is:", x)
print("minimum value is:", y)
# Out:
# maximum value is: 63
# minimum value is: 44
