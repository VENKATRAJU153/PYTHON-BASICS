# %% [markdown]
# <a href="https://colab.research.google.com/github/VENKATRAJU153/PYTHON-BASICS/blob/main/Function_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# functions practice

# %%
def my_functions(dic):
  print("name:", dic['name'])
  print("age:", dic['age'])
dic = ({"name": 'RAJU', "age":36})
my_functions(dic)
# Out:
# name: RAJU
# age: 36

# %%
def fun(name,age,birth,/) :
  print(name,age, birth)
fun("raj", 10, 35)
# Out:
# raj 10 35

# %%
from typing_extensions import ItemsView
def my_function(**kid):
  print("His last name is " + kid["fname"])

my_function(fname = "Tobias", lname = "Refsnes")
# Out:
# His last name is Tobias

# %%
def my_fun(greet,*names):
  for i in names:
    print(greet," ", i)
my_fun("hello",'RAJU','ROOPA','RANI')
# Out:
# hello   RAJU
# hello   ROOPA
# hello   RANI

# %%
def myfunc1():
  x = "Jane"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())
# Out:
# hello

# %%
x = lambda a,b,c:a**b+ c
a = int(input())
b = int(input())
c = int(input())
print(x(a,b,c))
# Out:
# 2
# 4
# 6
# 22

# %%
import json

print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
print(json.dumps(None))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
# null

# %%
import re

#Check if the string starts with "The" and ends with "Spain":

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)

if x:
  print("YES! We have a match!")
else:
  print("No match")
# Out:
# YES! We have a match!

# %%
import re

txt = "The rain in Spain"

#Check if "Portugal" is in the string:

x = re.findall("Portugal", txt)
print(x)

if (x):
  print("Yes, there is at least one match!")
else:
  print("No match")
