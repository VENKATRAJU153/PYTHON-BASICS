# %%
a=50

# %%
b=20
c=a*b
print(c)
# Out:
# 1000

# %%
from re import L
k=17852
l=2
m=k*l
print(m)
# Out:
# 35704

# %%
g=6125
h=25
v=g/h
print(v)
# Out:
# 245.0

# %%
print(type(v))
# Out:
# <class 'float'>

# %%
print(id(v))
# Out:
# 140122166140848

# %%
v=255

# %%
print(v)
print(id(v))
# Out:
# 255
# 10765864
